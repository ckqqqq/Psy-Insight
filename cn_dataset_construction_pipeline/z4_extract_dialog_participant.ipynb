# %%
# import json
# input_file_path="/home/ckqsudo/code2024/0dataset/E-bed/Chinese/中文心理数据集_处理错误reasoning.json"
# with open(input_file_path,"r",encoding="utf-8") as i_f:
#     cn_data=json.load(i_f)

# %%
# # cn_data
# participant=["治疗师","来访者"]
# participant_num=2
# for idx in range(len(cn_data)-1,-1,-1):
#     item=cn_data[idx]
#     if item["key"]=="dialog_id" and item["type"]=="双人对话":
#         participant_num=2
#         participant=["治疗师","来访者"]
#         cn_data[idx]["source"]=cn_data[idx-1]["source"]
#     elif  item["key"]=="dialog_id" and item["type"]=="多人对话":
#         participant_num=3
#         participant=[]
#         cn_data[idx]["source"]=cn_data[idx-1]["source"]
#     if item["key"]=="fewshot":
#         cn_data[idx]["participant_num"]=participant_num
#         cn_data[idx]["participant"]=participant

# %%
# import json
# with open(r"/home/ckqsudo/code2024/0dataset/E-bed/Chinese/中文心理数据集_处理错误reasoning_统计参与者.json","w") as o_f:
#     json.dump(cn_data,o_f,ensure_ascii=False)

# %%
# len(cn_data)

# %%
import json
input_file_path="/home/ckqsudo/code2024/0dataset/E-bed/Chinese/中文心理数据集_处理错误reasoning_统计参与者.json"
with open(input_file_path,"r",encoding="utf-8") as i_f:
    cn_data=json.load(i_f)

# %%
print_participant=[]
for idx,item in enumerate(cn_data):
    participant=set()
    if item['key']=="fewshot":
        for y,dialog_item in enumerate(item['dialog']):
            participant.add(dialog_item["origin_text"].split("：")[0])
        print_participant.append(tuple(participant))

# %%
from collections import Counter
# Counter(print_participant)

# %%
total_participant=[]
for i in print_participant:
    for item in i:
        total_participant.append(item)
total_participant.sort()

# %%
list(set(total_participant))
# print_participant[0][0]
# Out:
# ['来访者的孩子乔治（看着治疗师）',
#  '来访者的孩子苏珊',
#  '治疗师（在暂停休息十分钟后，治疗师总结）',
#  '来访者',
#  '来访者露丝（在停顿了两分钟之后）',
#  '来访者（停顿了一下，接着爆发一样地大声喊道）',
#  '来访者（想了一下）',
#  '来访者（看起来很疑感，但是在思考）',
#  '来访者露丝',
#  '来访者（提高了声音、充满了情绪）',
#  '来访者（笑了起来）',
#  '治疗师',
#  '来访者的丈夫约翰（打断了来访者的孩子乔治）',
#  '治疗师（关注来访者和来访者的丈夫约翰）',
#  '来访者的孩子詹妮弗',
#  '来访者的孩子亚当',
#  '来访者的母亲丽娜',
#  '来访者的孩子乔治（对治疗师）',
#  '来访者（冲着另外一张椅子）',
#  '治疗师（对来访者的孩子乔治）',
#  '来访者的丈夫约翰（对治疗师）',
#  '来访者（对来访者的丈夫约翰）',
#  '来访者（打断了并转向来访者）',
#  '来访者（看起来很气）',
#  '来访者的丈夫史密斯',
#  '来访者的孩子乔治',
#  '来访者的孩子乔治（想了一会儿）',
#  '来访者（不知所措）（疑惑）',
#  '治疗师（笑）',
#  '来访者（坚定地点头）',
#  '来访者（微笑）',
#  '治疗师（并没有因此而开始和来访者进行争论，而是继续讲）',
#  '来访者的孩子乔治（不情愿地）',
#  '对来访者的孩子詹妮弗',
#  '来访者的丈夫约翰（看着来访者的孩子乔治，停顿了很久）',
#  '来访者（深深叹了口气）',
#  '来访者的孩子乔治（看着来访者和来访者的丈夫约翰）',
#  '来访者（这引发了她一些强烈的感受，来访者很长一一段时间都没有讲话，她只是安静地坐在那里，抱着“孩子”并温柔地抚摸着它）',
#  '来访者（又一次转向了我）',
#  '来访者（柔和地）',
#  '治疗师（对来访者和来访者的丈夫约翰）',
#  '来访者的丈夫约翰',
#  '来访者的孩子乔治（热泪盈眶）',
#  '来访者的母亲莉娜',
#  '治疗师（特别强调）',
#  '治疗师（对于来访者）',
#  '来访者的孩子罗伯特',
#  '来访者的丈夫约翰（生气地打断了来访者的孩子乔治）',
# ...

# %% [markdown]
# 在正则表达式中，最简单的方法就是把问题转为原子问题，例如在括号匹配中要匹配的括号类型有很多，最好的方法就是把异常的括号都转换为中文括号，这样才最容易匹配那些阴间括号组合

# %%
#import regex
# simple_para = regex.compile(r'\([^\(\)（）]{,30}\)|（[^\(\)（）]{,30}\)|\([^\(\)（）]{,30}）|（[^\(\)（）]{,30}）|【[^\(\)（）]{,30}】|「[^\(\)（）]{,30}】|【[^\(\)（）]{,30}]|\[[^\(\)（）]{,30}】|「.*]|‘|］[^\］]{,30}|］|「[^\］]{,30}「|］|【[^\］]{,30}【|］|「[^\］]{,30}「')
# # simple_para = regex.compile(r'\([^\(\)（）]*?\)|（[^\(\)（）]*?\)|\([^\(\)（）]*?）|（[^\(\)（）]*?）|【[^\(\)（）]*?】|「[^\(\)（）]*?】|【[^\(\)（）]*?]|\[[^\(\)（）]*?】|「.*?]|‘|］[^\］]*?|］|「[^\］]*?「|］|【[^\］]*?【|］|「[^\］]*?「')
# # 「停顿]【停顿］

# %%
import regex
# simple_para = regex.compile(r"\[(.+?)\]")

# %%
# # simple_para.findall("治疗师：[轻轻地微笑，带着轻柔的悲伤：我在她脸上看到一些东西］你在担心离开？[长时间地停顿]")
# import regex
# simple_para = regex.compile(r'\((?:[^\(\)（）]*\)|[^\(\)（）]*)|（(?:[^\(\)（）]*\)|[^\(\)（）]*)|【(?:[^\(\)（）]*】|[^\(\)（）]*)|「(?:[^\(\)（）]*」|[^\(\)（）]*)')
# simple_para= regex.compile(r'\[((?:(?!\[|\]).)*?)\]|\[((?:(?!\[|\]).)*?)\］|【((?:(?!\[|\]).)*?)］|「((?:(?!\[|\]).)*?)］|\([^\(\)（）]{,30}\)|（[^\(\)（）]{,30}\)|\([^\(\)（）]{,30}）|（[^\(\)（）]{,30}）|【[^\(\)（）]{,30}】|「[^\(\)（）]{,30}】|【[^\(\)（）]{,30}]|\[[^\(\)（）]{,30}】|「.*】|‘|］[^\］]{,30}|］|「[^\］]{,30}「|］|【[^\］]{,30}【|］|「[^\］]{,30}「')
# text="治疗师：[轻轻地微笑，带着轻柔的悲伤：我在她脸上看到一些东西］你在担心离开？[长时间地停顿] 治疗师：【在同一个面谈中的几分钟后，接着她刚讲过的什么话］「微笑着］如果你看着录像，它会把我的脸放在你的眼前，而不是你自己去看。"
# # simple_para = regex.compile(r"\[((?:(?!\[|\]).)*?)\]|\[((?:(?!\[|\]).)*?)\］|【((?:(?!\[|\]).)*?)］|「((?:(?!\[|\]).)*?)］")
# simple_para.findall(text)

# %%
# matches

# %%
# "「笑····我已经这样做过几次了。"
# "（笑）我已经这样做过几次了。"
# "取代惯怒的是什么呢？"
# "取代愤怒的是什么呢？"

# %%
a=["1234","2314"]
b=["1234","2314"]
a==b
# Out:
# True

# %%
import regex
simple_para = regex.compile(r'\([^\(\)（）]{,30}\)|（[^\(\)（）]{,30}\)|\([^\(\)（）]{,30}）|（[^\(\)（）]{,30}）|【[^\(\)（）]{,30}】')
res=[]
szk_res=[]
for idx,item in enumerate(cn_data):
    participant=set()
    if item['key']=="fewshot":
        for y,dialog_item in enumerate(item['dialog']):
            action_list=None
            action_list=simple_para.findall(dialog_item['origin_text'])
            if action_list:
                res.extend(action_list)
                print(action_list)
                if 'action_labels' in dialog_item:
                    print(action_list==dialog_item['action_labels'],)
                    szk_res.extend(dialog_item['action_labels'])
                else:
                    print("补充",dialog_item['origin_text'])
# Out:
# ['（停顿）', '（停顿）', '（停顿）']
# True
# ['（停顿）']
# True
# ['（看起来很气）']
# True
# ['（来访者肯定地点了点头）']
# True
# ['（停顿）']
# True
# ['（坚定地点头）']
# True
# ['（停顿）']
# True
# ['（柔和地）']
# True
# ['（停顿）']
# True
# ['（对来访者的丈夫约翰）']
# True
# ['（注视着来访者）']
# True
# ['（对着来访者）']
# True
# ['（对着治疗师）']
# False
# ['（停顿）', '（停顿）']
# True
# ['（微笑地）']
# True
# ['（对来访者）']
# True
# ['（觉得荒谬）']
# True
# ['（微笑着）', '（对约翰）']
# False
# ['（打断了来访者）']
# True
# ['（并没有因此而开始和来访者进行争论，而是继续讲）']
# 补充 治疗师（并没有因此而开始和来访者进行争论，而是继续讲）：假设我在半夜给你打电话并且在你选择恐慌之前就把你叫醒了。事实上，现在就让我们这么做。假设你现在在睡觉，而我给你打了个电话。
# ['（特别强调）']
# True
# ['（她描述了自己希望从文夫那里获得的东西。）']
# True
# ['（笑了起来）']
# True
# ['（来访者开始哭泣）', '（来访者继续哭泣，接着是一段时间的沉默）']
# True
# ['（在椅子上焦躁不安地扭动着身体并迅速将眼光挪开）']
# True
# ['（几分钟之后）']
# True
# ['（她停了下来，做了个深呼吸）']
# True
# ['（脸上带着略微惊讶的表情）', '（她微笑了起来）']
# True
# ['（来访者的叙述又出现了变化，她安静了下来，开始流泪）']
# 补充 来访者：我想象着我的父亲和丈夫也在这里，我对他们也感到愤怒。我也不知道他们想从我这里获得什么（来访者的叙述又出现了变化，她安静了下来，开始流泪）。
# ['（我在鼓励她将她一直在头脑中不停告诉自己的话大声地讲出来）']
# ...

# %%
# str2 = str1.replace("个", "", 1)

# %%
res_action_list=list(set(res))

# %%
res_action_list
# Out:
# ['（治疗师帮助来访者用想像的方式生动地回忆该情景）',
#  '（即病症分类与预后）',
#  '（总结会读的前一部分，在纸上记录下自动思维，让双方都可以看到）',
#  '（第一个养母）',
#  '（collectivesymbol）',
#  '（平静些）',
#  '（停住）',
#  '（几分钟之后）',
#  '（深深叹了口气）',
#  '（提一些问题加以指导）',
#  '（支持并鼓励当事人）',
#  '（很激动地）',
#  '（每个人都在偷偷笑）',
#  '（靠着椅背，将椅子向后挪）',
#  '（看起来很疑感，但是在思考）',
#  '（愤怒地）',
#  '（仍然看看是否有其他任何重要的维）',
#  '（打断了来访者）',
#  '（忽略来访者的挑鲜）',
#  '（识别独特的结果）',
#  '（Basch，1977）',
#  '（讥讽地）',
#  '（什么问题或情境）',
#  '（就这样做了）',
#  '（来访者没作声，也没有反应。）',
#  '（1）',
#  '（有三名成员点头同意）',
#  '（来访者的名学）',
#  '（治疗师把来访者的手放在他的腹部，让他“向其中”吸气）',
#  '（长时间的暂停）',
#  '（温柔地）',
#  '（直接赞美来访者的可贵改变）',
#  '（冲着另外一张椅子）',
#  '（开始问题解决，让患者起主导作用。）',
#  '（没有反应）',
#  '（测试来访者观点能否持续很久）',
#  '（描绘愿景的图像）',
#  '（自我赞美）',
#  '（肯定已经做到之处，企图使个人优势意识化）',
#  '（根据来访者的回答，再次确认来访者会谈自标）',
#  '（大步穿过房间，走向门口）',
#  '（关系问句，间接赞美）',
#  '（直接对来访者的丈夫约翰）',
#  '（轻轻地打断）',
#  '（一般化来访者的情绪）',
#  '（那样写下）',
#  '（企图寻找一小步）',
#  '（使用来访者用字，复述来访者在意之处）',
#  '（尽力发现在患者的思维中是否有扭曲）',
#  '（感动状）',
#  '（停了一会几）',
#  '（我的头倾斜着，倚向前方，用右手做着手势）',
#  '（好奇了解细节）',
# ...

# %%
len(res_action_list)
# Out:
# 542

# %%
# import re
# del_list=[]
# def has_chinese(text):
#     pattern = r'[\u4e00-\u9fa5]'
#     return re.search(pattern, text)
# for idx,item in enumerate(res_action_list):
#     if not has_chinese(item[1:-1]) or "见图" in item :
#         print(item)
#         del_list.append(item)
#         res_action_list.remove(item)

# %%
len(res_action_list)
# Out:
# 542

# %%
# szk_res=list(set(szk_res))
# len(szk_res)

# %%
len(res_action_list)
# Out:
# 542

# %%
# # print(res_action_list[100])
# reasoning=[]
# action_labels=[]
# multi_participant_act=[]
# # action_labels=
# for item in res_action_list:
#     if "扮演" in item or "对" in item and "来访者" in item:
#         multi_participant_act.append(item)
#         res_action_list.remove(item)

# %%
# =['（直接对来访者的丈夫约翰）',
#  '（对来访者）',
#  '（复述来访者在意的愿景细节用学，提高来访者对完成目标的承诺）',
#  '（妻子扮演丈夫）',
#  '（治疗师要求来访者直接面对他的父亲）',
#  '（对来访者的母亲）',
#  '（丈夫扮演妻子）',
#  '（来访者继续写下适应性反应及对每一陈述相信的程度）',
#  '（对来访者的孩子乔治）',
#  '（对来访者和来访者的丈夫约翰）',
#  '（对来访者的孩子詹妮弗）',
#  '（对于来访者）',
#  '（对来访者的丈夫约翰）',
#  '（对来访者的母亲丽娜）',
#  '（那是来访者调动出来用以对抗焦虑的防御）',
#  '（对着来访者）',
#  '（来访者暧昧对象）',
#  '（对来访者的孩子乔治和来访者的丈夫约翰）']

# %%
# res_action_list[300:]

# %%
# for i in res_action_list[:300]:
#     if i not in tmp:
#         del_list.append(i)

# %%
del_list=['（collectivesymbol）',
 '（Basch，1977）',
 '（1）',
 '（见图8一1）',
 '（1915b）',
 '（face-talk）',
 '（face）',
 '（narcissisticsurplus）',
 '（1917）',
 '（unfinishedbusiness）',
 '（MaryEngel）',
 '（3)',
 '(95%)',
 '（1971）',
 '（7）',
 '（PeteRose）',
 '（symptomneuroses）',
 '（见图8-1)',
 '（5）',
 '（Seligman，1975）',
 '（6）',
 '（4）',
 '（2）',
 '（即病症分类与预后）',
 '（第一个养母）',
 '（EARS）',
  '（乘声地）',
  '（展开EARS）',
   '（草录来访者的项目)',
'（1913年）',
'（在第十二章中已经提过治疗师与来访者一起制定应付卡)',
 '（阀读并沉患新的信念)','(D治疗师R)'
 ]

# %%
# 对于来访者的孩子
multi_participant_act=['（对来访者）',
 '（对着来访者的丈夫约翰）',
 '（妻子扮演丈夫）',
 '（治疗师要求来访者直接面对他的父亲）',
 '（对来访者的母亲）',
 '（丈夫扮演妻子）',
 '（对来访者的孩子乔治）',
 '（对来访者和来访者的丈夫约翰）',
 '（对来访者的孩子詹妮弗）',
 '（对于来访者）',
 '（对来访者的丈夫约翰）',
 '（对来访者的母亲丽娜）',
 '（对着来访者）',
 '（来访者暧昧对象）',
 '（对来访者的孩子乔治和来访者的丈夫约翰）',
  '（对妻子）',
  '（对约翰）',
  ' （关注来访者和来访者的丈夫约翰）']
for i in multi_participant_act:
    if i not in res_action_list:
        print(i)
        # multi_participant_act.remove(i)
# Out:
# （对着来访者的丈夫约翰）
#  （关注来访者和来访者的丈夫约翰）

# %%
# multi_participant_act

# %%
len(res_action_list)
# Out:
# 542

# %%
for i in del_list:
    if i in res_action_list:
        res_action_list.remove(i)
for i in multi_participant_act:
    if i in res_action_list:
        res_action_list.remove(i)

# %%
len(res_action_list)
# Out:
# 494

# %%
# reasoning=[]
# for i in res_action_list:
#     if i not in dialog_actions:
#         reasoning.append(i)

# %%
reasoning=['（治疗师帮助来访者用想像的方式生动地回忆该情景）',
 '（总结会读的前一部分，在纸上记录下自动思维，让双方都可以看到）',
 '（提一些问题加以指导）',
 '（仍然看看是否有其他任何重要的维）',
 '（治疗师和来访者随着想像进入最让患考感到痛苦的时刻)',
 '（开始问题解决，让患者起主导作用。）',
 '（地不能完成经济学作业的自动思维）',
 '（引发自我赞美）',
 '（重新建构以找到来访者的优势）',
 '（他们更具体地讨论这个主题）',
 '（因为这一实际问题）',
 '（指导患者摘述，就像正在发生一样)',
 '（运用当事人的用字，理解来访者主观看法）',
 '（从更深入的角度去探讨问题造成的影响）',
 '（成果问句：目标导向的开场）',
 '（自然同理）',
 '（帮助来访者持征性地思维）',
 '（独特的叙述方式的问题）',
 '（以评量问句，找寻进展而赞美之）',
 '（反映来访者的在乎，企图推进自标的形成）',
 '（重复来访者的大自标）',
 '（笼统地回答)',
 '（在进行问题解决之前，用这个问题加强认知模式。)',
 '（我在鼓励她将她一直在头脑中不停告诉自己的话大声地讲出来）',
 '（忽略来访者的挑鲜）',
 '（识别独特的结果）',
 '（什么问题或情境）',
 '（直接赞美来访者的可贵改变）',
 '（测试来访者观点能否持续很久）',
 '（肯定已经做到之处，企图使个人优势意识化）',
 '（关系问句，间接赞美）',
 '（一般化来访者的情绪）',
 '（使用来访者用字，复述来访者在意之处）',
 '（联结与自标的关系）',
 '（尝试从重要他人观点，找寻达成自标的优势）',
 '（了解现状与自标的差距，企图找寻下一步行动）',
 '（继续形成会谈初步大方向）',
 '（假设间句结合关系问句）',
 '（根据建议，尝试引导来访者再次觉察改变的发生）',
 '（EARS再次启动）',
 '（开放性问句，应对问句）',
 '（联结之前提及的优势）',
 '（他所获得的对自我的新认识）',
 '（发展更具体的小自标）',
 '（用来访者的话总结）',
 '（先总结）',
 '（核心信念)',
 '（一般性回应）',
 '（我不适当核心信念）',
 '（形成谈初步大方向）',
 '(强化认知模式)',
 '（再次复述来访者目标的重要性，以提高承诺）',
 '（寻我一个另外的解释）',
 '（转而有点愤怒）',
 '（了解会谈的终点）',
 '（奇迹问句，尝试建构来访者的愿景）',
 '（再次肯定来访者形成的新目标）',
 '（让来访者“重放”当时的体验，犹如现在正发生着一样)',
 '（赞美当事人）',
 '（通过负向情绪，反映其中的看重之处）',
 '（帮助意者以一个更易操纵的形式聚焦并分解问题）',
 '（记录或让患者将“父亲的车祸”记录于纸的底端）',
 '（明确性回应，尝试支持并理解其情绪的状态）',
 '（再追问奇迹发生后的细节，以建立偏好未来的愿景）',
 '（再次尝试间接赞美，找寻优势）',
 '（试图使得这个经历在来访者的脑海中更逼真生动的再现）',
 '（巧妙的加强认知模式）',
 '（再次尝试建立正向所欲的自标）',
 '（了解改变后的现况）',
 '（重新建构，以反映既存资源）',
 '（根据来访者的回答，再次确认来访者会谈自标）',
 '（共情、重新建构确认来访者的在乎）',
 '（引发来访者的自我赞美）',
 '（运用关系问句的间接赞美）',
 '（总结从刚刚完成的前头向下技术中他们所学到的知识）',
 '（评量问句）',
 '（直接赞美来访者的优点与自标）',
 '（汇整前述的转变，再次引导来访者自己赞美其进展）',
 '（成果问句，初步形成咨询自标）',
 '（我开始引导进行客观化的对话过程）',
 '（尝试确认其想追求的目标）',
 '（再次直接赞美当事人的小小改变）',
 '（提出基本原则）',
 '（再次尝试间接赞美）',
 '（反映来访者的优势，并引发自我赞美）',
 '（使用来访者用字，一般化其反应）',
 '（仍然评估来访者是否有思维障碍）',
 '（帮助来访者更具体地思考）',
 '（引发来访者意识改变的方法）',
 '（继续讨论具体情境下的可行行动）',
 '（假设间句）',
 '（透过奇迹愿景，尝试回忆过去的成功例外）',
 '（捕捉当事人已经做到的改变，并扩大进展）',
 '（企图肯定赞美，确认改变并辨认自助力量）',
 '（深入探索例外，使其意识化)',
 '（赞美与应对问句）',
 '（举出与预期答案相反的情绪来慢慢唤起地的回忆）',
 '（探讨自发应对方法）',
 '（寻找一个更全面的图像；确定是否有其他重要的自动思维。）',
 '（重复我认为我听到的）',
 '（使替代性的故事具体化）',
 '（加强其感情以促进记忆的恢复)',
 '（使她形成特定的时间）',
 '（以来访者用词问开放性问句）',
 '（开始寻找下一步的自标）',
 '（在目标设定过程中鼓励来访者更积极的参与）',
 '（探索和问题性故事相关联的主题和情节）',
 '（开放式问句）',
 '（在继续就此进行了更加深入的探索之后）',
 '（一般化的支持）',
 '（肯定自标）',
 '（尝试激发未来可能性）',
 '（回应关键字）',
 '（确认有效行动）',
 '（质疑）',
 '（直接赞美）',
 '（核心信念）',
 '（尝试寻找我既存的例外资源）',
 '（赞美）',
 '（开始了评估自动思维的过程)',
 '（尊重当事人的方向，尝试建构良好的自标）',
 '(治疗师选择了一一万短文，他认为来访者能够理解)',
 '（确认有无新的进展）',
 '（给予一个相反的例子）',
 '（已经的评估，有正常理由对该问题无需做选一步工作）',
 '（再次尝试引发自我赞美）',
 '（继续建立具体可行的自标）',
 '（强化进展）',
 '（检查一下来访者是否还记得这样布置的理由)',
 '（再次引发小改变的觉察）',
 '（了解已做处理及其效果）',
 '（开放性问句）',
 '（发展正向所欲的自标）',
 '（检视连锁效果）',
 '（来访者继续写下适应性反应及对每一陈述相信的程度）',
 '（假设问句结合关系问句）',
 '（一直重复最开始的那句话）',
 '（以评量问句了解现况）',
 '（来访者表达了希望回到治疗的想法）',
 '（假设问句，形成下一步的大方向，再重复上述阶段）',
 '（重新建构，赞美来访者的优势）',
 '（帮助来访者优先考虑地的问题）',
 '（透过新的进展，来访者产生新目标）',
 '（自然共情）',
 '（自我赞美，并让决定权和会谈焦点回到来访者身上）',
 '（讨论复发应对）',
 '（引导来访者以正向所欲的语言表述自标）',
 '（引导自标由正向抽象概念转为具体表现）',
 '（扩大效果）',
 '（继续讨论如何勇敢地跨出第一步去请亲戚帮忙）',
 '（箭头向下技术）',
 '（使用慧者使用的特殊的行为术语“幸福”和“感觉好些”）',
 '（赞美，明确性回应）',
 '（引出持殊的事件)',
 '（肯定支持）',
 '（描述交谈内容）',
 '（汇报的是情绪及生理反应，而不是自动思维）',
 '（自标确认：从多中选一）',
 '（了解来访者与问题的互动）',
 '（了解当事人主观知觉）',
 '（引发进展的意识）',
 '（关系问句）',
 '（重复我认为我听到的)',
 '（赞美强调进步）',
 '（通过他人眼光，尝试寻找优势力量）',
 '（填上“理想馅饼”）',
 '（好奇地将会谈焦点回到自我可控之处）',
 '（让愿景正向行动化）',
 '（用关系问句，让来访者的自标更为人际情境化）',
 '（变得更为情绪化）',
 '（尝试以评量问句寻找例外）',
 '（用一个类似的此俞经常使来访者从不同的角度看待她的情境)',
 '（并没有因此而开始和来访者进行争论，而是继续讲）',
 '（摘要，表示倾听，确认理解）',
 '（思考）',
 '（成果问句）',
 '（注视着来访者）',
 '（支持并鼓励当事人）',
 '（总结）',
 '（直接赞美来访者的现实感）',
 '（强化进展的重要性）',
 '（运用关系问句，继续让愿景正向明朗化）',
 '（独特的叙述方式问题）',
 '（运用关系问句以间接赞美）',
 '（反复或强调自动思维记录表上的这个问题 )',
 '（汇整前述内容，展现倾听态度，建立“理解基础”）',
 '（尽力发现在患者的思维中是否有扭曲）',
 '（治疗师帮助来访者用想像的方式生动地回忆该情景）']

# %%
for i in reasoning:
    if i not in res_action_list:
        print(i)

# %%
# for i in reasoning:
#     if i not in res_action_list:
#         print(i)
#         for item in res_action_list:
#             if i[:len(i)//2] in item or i[len(i)//2:] in item:
#                 reasoning.remove(i)
#                 reasoning.append(item)
#                 print("hei",item)
#                 break
# Out:
# （尽力发现在患素的思维中是否有扭曲）
# hei （尽力发现在患者的思维中是否有扭曲）
# （治疗师）
# hei （治疗师帮助来访者用想像的方式生动地回忆该情景）
# （反复或强调 D治疗师R 上的这个问题 )

# %%
reasoning
# Out:
# ['（治疗师帮助来访者用想像的方式生动地回忆该情景）',
#  '（总结会读的前一部分，在纸上记录下自动思维，让双方都可以看到）',
#  '（提一些问题加以指导）',
#  '（仍然看看是否有其他任何重要的维）',
#  '（治疗师和来访者随着想像进入最让患考感到痛苦的时刻)',
#  '（开始问题解决，让患者起主导作用。）',
#  '（地不能完成经济学作业的自动思维）',
#  '（引发自我赞美）',
#  '（重新建构以找到来访者的优势）',
#  '（他们更具体地讨论这个主题）',
#  '（因为这一实际问题）',
#  '（指导患者摘述，就像正在发生一样)',
#  '（运用当事人的用字，理解来访者主观看法）',
#  '（从更深入的角度去探讨问题造成的影响）',
#  '（成果问句：目标导向的开场）',
#  '（自然同理）',
#  '（帮助来访者持征性地思维）',
#  '（独特的叙述方式的问题）',
#  '（以评量问句，找寻进展而赞美之）',
#  '（反映来访者的在乎，企图推进自标的形成）',
#  '（重复来访者的大自标）',
#  '（笼统地回答)',
#  '（在进行问题解决之前，用这个问题加强认知模式。)',
#  '（我在鼓励她将她一直在头脑中不停告诉自己的话大声地讲出来）',
#  '（忽略来访者的挑鲜）',
#  '（识别独特的结果）',
#  '（什么问题或情境）',
#  '（直接赞美来访者的可贵改变）',
#  '（测试来访者观点能否持续很久）',
#  '（肯定已经做到之处，企图使个人优势意识化）',
#  '（关系问句，间接赞美）',
#  '（一般化来访者的情绪）',
#  '（使用来访者用字，复述来访者在意之处）',
#  '（联结与自标的关系）',
#  '（尝试从重要他人观点，找寻达成自标的优势）',
#  '（了解现状与自标的差距，企图找寻下一步行动）',
#  '（继续形成会谈初步大方向）',
#  '（假设间句结合关系问句）',
#  '（根据建议，尝试引导来访者再次觉察改变的发生）',
#  '（EARS再次启动）',
#  '（开放性问句，应对问句）',
#  '（联结之前提及的优势）',
#  '（他所获得的对自我的新认识）',
#  '（发展更具体的小自标）',
# ...

# %%
# for i in dialog_actions:
#     if i not in res_action_list:
#         print(i)
#         for item in res_action_list:
#             if i[:len(i)//2] in item or i[len(i)//2:] in item:
#                 dialog_actions.remove(i)
#                 dialog_actions.append(item)
#                 print("hei",item)
#                 break
# Out:
# （惊恐，关切地握着他的手，柔和地说）
# hei （惊讶，关切地握着他的手，柔和地说）
# （模仿教授粗备的声音)
# hei （模仿教授粗鲁的声音)
# （突泣)
# hei （哭泣)
# （咳开嘴笑了，有点不好意思，冲我挥挥手，离开了）
# hei （咧开嘴笑了，有点不好意思，冲我挥挥手，离开了）
# （停顿]，我[停顿)
# （突得更凶）
# hei （变得更凶）
# （脸上带着略微惊恐的表情）
# hei （脸上带着略微惊讶的表情）
# （背定地点头）
# hei （坚定地点头）

# %%
dialog_actions=['（平静些）',
 '（停住）',
 '（几分钟之后）',
 '（深深叹了口气）',
 '（很激动地）',
 '（每个人都在偷偷笑）',
 '（靠着椅背，将椅子向后挪）',
 '（看起来很疑感，但是在思考）',
 '（愤怒地）',
 '（打断了来访者）',
 '（讥讽地）',
 '（就这样做了）',
 '（来访者没作声，也没有反应。）',
 '（有三名成员点头同意）',
 '（来访者的名学）',
 '（治疗师把来访者的手放在他的腹部，让他“向其中”吸气）',
 '（长时间的暂停）',
 '（温柔地）',
 '（冲着另外一张椅子）',
 '（迷茫状）',
 '（没有反应）',
 '（描绘愿景的图像）',
 '（自我赞美）',
 '（大步穿过房间，走向门口）',
 '（轻轻地打断）',
 '（那样写下）',
 '（企图寻找一小步）',
 '（感动状）',
 '（停了一会几）',
 '（我的头倾斜着，倚向前方，用右手做着手势）',
 '（好奇了解细节）',
 '（第二个）',
 '（西班牙语，意思是谚语）',
 '（用患者准确的调）',
 '（抽唾）',
 '（点头)',
 '（西班牙语，意思是不入虎穴為得虎子）',
 '（闭上眼）',
 '（伸出手来）',
 '（来访者继续哭泣，接着是一段时间的沉默）',
 '(开始流洱）',
 '（表情明显发生变化，眼睛也湿润了）',
 '（继续）',
 '（注意到来访者突然间看起来垂头丧气）',
 '（和意象）',
 '（来访者看起来有点不适）',
 '（画好）',
 '（长时间地停顿)',
 '（她）',
 '（或者读应付卡，或者练习控制呼吸或记录我的活动）',
 '（深深地叹了一口气）',
 '（建议）',
 '（笑了）',
 '（或者你小孩的/其他人的/家庭成员的生命）',
 '（看着来访者的孩子乔治，停顿了很久）',
 '（较平和地）',
 '（您心里正在想什么？）',
 '(阅读文章)',
 '（起身）',
 '（记下指导语）',
 '（虽然根据我的想象我不确定他能做到）',
 '（写下它）',
 '（微笑）',
 '（指第二个养母）',
 '（烦躁）',
 '（点头表示同意）',
 '（没有声音）',
 '（特别强调）',
 '（照这样做）',
 '（所有人都笑了起来）',
 '（我）',
 '（又一次脸红）',
 '（又一次转向了我）',
 '（在同一个面谈中的几分钟后，接着她刚讲过的什么话)',
 '(治疗师和来访者利用几分钟进行讨论。）',
 '（犹豫地）',
 '（愤怒）',
 '（仍在哭)',
 '（渐渐平静）',
 '（迟到了10分钟，对他来说这有点不寻常）',
 '（按上述写好）',
 '（或）',
 '（领养机构的负责人）',
 '（惊烤）',
 '（觉得荒谬）',
 '（身体朝向来访者的丈夫约翰）',
 '（她转向来访者的孩子乔治）',
 '（愉快起来）',
 '（疑惑）',
 '（在暂停休息十分钟后，治疗师总结）',
 '(销停）',
 '（自恋型人格障碍）',
 '（换了椅子）',
 '（取出一张纸）',
 '（不知所措）',
 '（语气正式）',
 '（来访者的叙述又出现了变化，她安静了下来，开始流泪）',
 '（来访者的丈夫史密斯和来访者两个人都点头。）',
 '（看着来访者和来访者的丈夫约翰）',
 '（一个人笑了起来）',
 '（尝试形成第一小步）',
 '（生气状）',
 '（轻柔地笑）',
 '（语言柔和）',
 '（眼泪开始奔涌而出，顺着脸颊流下）',
 '（来访者的眼泪掉了下来，她叹了一口气，然后安静了下来）',
 '（低头，很伤心)',
 '（显示愤怒)',
 '（用一种些微带有攻击性的语气）',
 '（谦虚地）',
 '（等了一会儿）',
 '（尤其是那些人格结构与精神性神经症患者相类似的人）',
 '（写作业）',
 '（边说边写）',
 '（来访者的丈夫约翰点头）',
 '（面对二人）',
 '（走出）',
 '（促使来访者更加觉察既存的资源）',
 '（想了一会儿)',
 '（等了10秒钟）',
 '（画一数字线）',
 '（假设性问句）',
 '(注意到来访者看起来有较多的焦虑)',
 '（暂停）',
 '（提高了声音、充满了情绪）',
 '（她的脸变红了）',
 '（另外一种探讨差异的方式）',
 '（他转向治疗师笑着问）',
 '（画了一个阶梯）',
 '（写下）',
 '（微微笑着说）',
 '（感兴趣）',
 '（困感地）',
 '（停顿）',
 '（爸爸妈妈重归于好）',
 '（苦楚地）',
 '（我的眉毛上扬)',
 '（笑)',
 '（眼眶中充满泪水）',
 '（愤怒，受伤）',
 '（可预测）',
 '（脸红，颇有些慌乱）',
 '（来访者停顿了一下）',
 '（长时间停顿)',
 '（很困难地微笑着）',
 '（打断了并转向来访者）',
 '（柔和起来，声音有些颤抖）',
 '（长时间地停顿）',
 '（哭泣）',
 '（想了一下）',
 '（应对问句）',
 '（注意到本节的时间快到了）',
 '（冷冷地，怀着难掩的愤怒）',
 '（在停顿了两分钟之后）',
 '（眼泪涌出）',
 '（笑）',
 '（想了一会儿）',
 '（短暂的停顿）',
 '（对着治疗师）',
 '（她停了下来，做了个深呼吸）',
 '（把自已的椅子挪得离乔治更近一些）',
 '（联结现实，好奇地）',
 '（来访者摔门而出。治疗师注意到她把太阳镜落在了桌上）',
 '（很激动）',
 '（停顿)',
 '（微笑着)',
 '（焦躁不安，眼晴看着地面）',
 '（来访者迟到了20分钟，这是以前没有过的）',
 '（看起来很气）',
 '（看起来没那么兴奋了）',
 '（低泣）',
 '（我在想）',
 '（依此写下）',
 '（这样做了）',
 '（对治疗师）',
 '（激动状）',
 '（柔和地）',
 '（流泪）',
 '（平静多了）',
 '（示意来罗伯特静下来，然后看着来访者）',
 '（犹豫不决）',
 '（来访者开始哭泣）',
 '（眼神闪亮）',
 '（战栗）',
 '（总结性地）',
 '（或者谈论听磁带这一部分)',
 '（眼神变得温柔）',
 '（暂停)',
 '（已经呼气吸气了几次）',
 '（微笑地）',
 '（停顿]，我[停顿)',
 '（当我准备叫室友保持厨房整洁时）',
 '（来访者记录）',
 '（微笑着）',
 '（胆怯的声音）',
 '（不情愿地）',
 '（没有声音)',
 '（停下，看着治疗师，等着进一步的指示）',
 '（即他们不愿与你在一起）',
 '（停了一会儿）',
 '（填在空格内）',
 '（开玩笑）',
 '（或者“我能肯定这项作业是不合适的。”）',
 '（她微笑了起来）',
 '（立即平静下来）',
 '（他已经放弃读法律的念头了么？读大学也一并放弃了么？）',
 '（洋洋得意地）',
 '（摘要来访者所在乎之处）',
 '（每个人都表示了同意）',
 '（提高了音量）',
 '（思考片刻）',
 '（奇怪地看着治疗师，不过他还是将脸转向了来访者的丈夫约翰）',
 '（脸红）',
 '（点点头）',
 '（所有人都笑了）',
 '（来访者填好量表)',
 '（粗略记下这些思维）',
 '（明显地愉快些）',
 '（看着来访者的孩子乔治）',
 '（来访者肯定地点了点头）',
 '（赞美的态度）',
 '（哭泣)',
 '（在靠纸上端处记下：“一侧疼痛，阑尾炎”）',
 '（点头，记下来）',
 '（他们刚刚-一起做的--份）',
 '（如此做了）',
 '（如此照办）',
 '（想）',
 '（他指向所有的家庭成员，除了来访者）',
 '（不好意思地笑了）',
 '（来访者点头）',
 '（昂首大步径直走出，“砰”地甩门）',
 '（坐下，看上去愉快，有活力）',
 '（等了一会）',
 '（维系时间挺长但没有结果的一段关系）',
 '（重复着我认为我听到的她的话)',
 '（收集更多信息）',
 '（使用当事人用字，整理来访者所述的奇迹图像）',
 '（或者是最初记忆之一）',
 '（他们在我们所困惑的领域里可能会更为擅长。）',
 '(所有人都笑了起来)',
 '（两人落座）',
 '(真诚地)',
 '（疑感地看着自己的父亲）',
 '（叹气）',
 '（无奈状）',
 '（治疗师让来访者生动地想像并描速这个痛苦的事情）',
 '（在犹豫了一阵并确认了这样做的价值之后）',
 '（与来访者握手）',
 '（毫不犹豫地）',
 '(记下)',
 '（来访者看起来充满了防御性）',
 '（迷感不解）',
 '（治疗师应当与男孩有直接的目光接触。）',
 '（热泪盈眶）',
 '（此刻她语气中的温和消失了，取而代之的是之前那种尖酸和愤怒）',
 '（开始哭泣）',
 '（桥梁）',
 '（她描述了自己希望从文夫那里获得的东西。）',
 '（害羞状）',
 '（没有回应，离开）',
 '（悲伤的）',
 '（他对个人形象的描画：机能健全的成年人）',
 '（无论男女）',
 '（如果我变得越来越紧张）',
 '（在面询结束时，来访者走到门口，突然停住，拍了拍衣服口袋）',
 '（泪水滑落，她猛地站起来，椅子翻倒在地她尖声叫道）',
 '（想了二会儿）',
 '（落泪）',
 '（看着治疗师）',
 '（我们都笑了）',
 '（看起来非常生气）',
 '（她转向詹妮弗）',
 '（哭起来）',
 '（点头）',
 '（“我的脑子不会一片空白是很重要的，因此它绝对不能这样”）',
 '（稳定些）',
 '（记录）',
 '（此刻愤怒之外，多了点罪疫感）',
 '（将该条记在近中间处）',
 '（笑了起来）',
 '（现在依然如此）',
 '（看上去很愤怒，眼眶含泪，起身离开）',
 '（哎气）',
 '（惊呀地）',
 '（第二个养母）',
 '（我假设为真）',
 '（停顿了一下，接着爆发一样地大声喊道）',
 '（来访者的前一位治疗师）',
 '（稍停）',
 '（握手）',
 '（写下指定的作业）',
 '（而不是商业问题）',
 '（确认状）',
 '（打断了来访者的孩子乔治）',
 '（沉默）',
 '（在椅子上焦躁不安地扭动着身体并迅速将眼光挪开）',
 '（惊讶，关切地握着他的手，柔和地说）',
 '（模仿教授粗鲁的声音)',
 '（哭泣)',
 '（咧开嘴笑了，有点不好意思，冲我挥挥手，离开了）',
 '（变得更凶）',
 '（脸上带着略微惊讶的表情）',
 '（坚定地点头）']
