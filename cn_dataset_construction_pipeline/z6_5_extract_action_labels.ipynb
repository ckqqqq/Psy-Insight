# %%
# res=[]
# for line in idata:
#     num,action_lis=line.split("@")
#     res.append({int(num):action_lis[:-1].split("$")})
#     # print(tmp_list)
#     # print(len(tmp_list))

# %%
# Out:
# [{5: ['（停顿）', '（停顿）', '（停顿）']},
#  {19: ['（停顿）']},
#  {27: ['（看起来很气）']},
#  {28: ['（来访者肯定地点了点头）']},
#  {29: ['（停顿）']},
#  {30: ['（背定地点头）']},
#  {34: ['（停顿）']},
#  {36: ['（柔和地）']},
#  {38: ['（停顿）']},
#  {40: ['（对着来访者）']},
#  {41: ['（注视着来访者）']},
#  {43: ['（对着来访者）']},
#  {50: ['（停顿）', '（停顿）']},
#  {54: ['（微笑地）']},
#  {57: ['（和来访者说）']},
#  {59: ['（一副觉得荒课的样子）']},
#  {60: ['（微笑着）', '（转向来访者）']},
#  {140: ['（打断了来访者）']},
#  {168: ['（特别强调）']},
#  {231: ['（她描述了自己希望从文夫那里获得的东西。）']},
#  {273: ['（笑了起来）']},
#  {331: ['（来访者开始哭泣）', '（来访者继续哭泣，接着是一段时间的沉默）']},
#  {408: ['（几分钟之后）']},
#  {411: ['（她停了下来，做了个深呼吸）']},
#  {417: ['（脸上带着略微惊诉的表情）', '（她微笑了起来）']},
#  {445: ['（深深地叹了一口气）']},
#  {453: ['（在犹豫了一阵并确认了这样做的价值之后）']},
#  {455: ['（变得更为情绪化）', '（眼眶中充满泪水）']},
#  {457: ['（停顿了一下，接着爆发一样地大声喊道）']},
#  {465: ['（冲着另外一张椅子）']},
#  {469: ['（她的脸变红了）']},
#  {471: ['（换了椅子）']},
#  {475: ['（我假设为真）']},
#  {505: ['（在停顿了两分钟之后）']},
#  {527: ['（有三名成员点头同意）']},
#  {531: ['（停顿）']},
#  {539: ['（短暂的停顿）']},
#  {555: ['（开始唻泣）']},
# ...

# %%
# action_labels=[]
# for id_list in res:
#     for item in id_list:
#         action_labels.append(item)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[373], line 2
#       1 action_labels=[]
# ----> 2 for k,v in res:
#       3     for item in v:
#       4         action_labels.append(item)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
res=[]
for list1 in id_action_list:
    for item in list1[-1]:
        res.append(item)

# %%
# list(set(res))
