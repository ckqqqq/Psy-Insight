# %%
# 合并结果并进行

# %%
def file_name2idx(file_name:str):
    return int(file_name.split("_")[-1].split(".")[0])
def idx2file_name(idx:int):
    return "d"+"_"+str(idx)+".json"

# %%
import json
import os
chat_dir_path="/home/ckqsudo/code2024/0dataset/E-bed/Chinese/ChatGPT_缓存文件夹"
files=os.listdir(chat_dir_path)
files.sort()
error_index_list=[]
for file_name in files:
    file_path=chat_dir_path+"/"+file_name
    if not os.path.isfile(file_path):
        continue
    try:
        with open(file_path,"r",encoding="utf-8") as i_f:
            process_item=json.load(i_f)
            # print(type(process_item))
            # print(type(process_item))
    except Exception as e:
        print(e)
        idx=file_name2idx(file_name)
        error_index_list.append(idx)
error_index_list
# Out:
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# [168, 170, 175, 183, 188, 251, 322, 411, 415, 418, 440]

# %%
error_index_list
# Out:
# [168, 170, 175, 183, 188, 251, 322, 411, 415, 418, 440]

# %%
# idx=[168,170, 175, 183, 188, 251, 322, 411, 415, 418, 440]

# %%
a={1:2}
b={2:3}
# a.extent(b)

# %%
idx_dialog_dict={}

# %%
reason_set=set()
for file_name in files:
    file_path=chat_dir_path+"/"+file_name
    idx=file_name2idx(file_name)
    if idx in error_index_list:
        continue
    if not os.path.isfile(file_path):
        continue
    try:
        with open(file_path,"r",encoding="utf-8") as i_f:
            gpt_res=json.load(i_f)
            if str(idx) in idx_dialog_dict:
                print(idx)
            if gpt_res:
                idx_dialog_dict[str(idx)]=gpt_res
            for dialog_item in gpt_res:
                # print(dialog_item["resoning"])
                # print()
                if dialog_item['reason']!="":
                    reason_set.add(dialog_item['reason'])
    except Exception as e:
        print(e,"error")
        idx=file_name2idx(file_name)
        error_index_list.append(idx)
# Out:
# 'reason' error
# 'reason' error
# 'reason' error
# 'reason' error

# %%
idx_dialog_dict.keys()
# Out:
# dict_keys(['0', '1', '10', '100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '12', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '13', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '14', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '15', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '16', '160', '161', '162', '163', '164', '165', '166', '167', '169', '17', '171', '172', '173', '174', '176', '177', '178', '179', '18', '180', '181', '182', '184', '185', '186', '187', '189', '19', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '2', '20', '200', '201', '202', '203', '204', '205', '206', '207', '208', '209', '21', '210', '211', '212', '213', '214', '215', '216', '217', '218', '219', '22', '220', '221', '222', '223', '224', '225', '226', '227', '228', '229', '23', '230', '231',
# ...

# %%
type(idx_dialog_dict["0"])
# Out:
# list

# %%
len(idx_dialog_dict)
# Out:
# 451

# %%
# type(idx_dialog_list[0]

# %%
reason_list=list(reason_set)

# %%
reason_list
# Out:
# ['“ching-chongchinamen"”->“ching-chong chinamen”',
#  '儿乎->几乎',
#  '展露心迹',
#  '喊->唉',
#  '删除1. 2. 3. 4. 逗号',
#  '逗号改为顿号',
#  '修改中文标点符号',
#  '党->会 意样->如何',
#  '唤->唉 住在一起,->住在一起， 逼->图',
#  '修改了错词和标点符号',
#  '添加句号 删除重复词',
#  '扣何->怎么办 如采->如果',
#  '删除一一',
#  '307-20',
#  '的伤->伤',
#  '删除多余的“儿”',
#  '衰叹->抱怨 贵任->权利',
#  '删除··',
#  '何不->为什么不',
#  '唤->唉 魅->虽然 删除…·',
#  '思维您->您的思维 如装->如发现 水远->虽然',
#  '“一种”',
#  '仗->拿 出->拿出',
#  '修改标点符号和格式',
#  '一一-> 删除 唤->唉',
#  '信念->的信念 删除逗号',
#  '剪->好',
#  '帮助解决问题',
#  '在街上打电话给我',
#  '删除n',
#  '一一->不管',
#  '将都改为的',
#  '首光->首先',
#  '会读->会谈 一一->：',
#  '看到->感受到',
#  '基至->并不一定',
#  '贵->责',
#  '很对->很重要',
#  '删除多余的逗号',
#  '戒进来->加入治疗之前 训练我作些事',
#  '一一样->一样',
#  '蓬字遂可->明白理解',
#  '吗 带进',
#  '一决定->开始 一开始->开始',
#  '担白->但白',
#  '出现了 多谈论',
#  '患于->想',
#  '据治疗前我们所谈的->根据我们之前的谈话 这是通常你如何看待你势力的态度吗？即知采你不尽可能地势力工作，你就会失败？',
#  '预言->预测 会谈->次会谈 需时->需要',
#  '势力->努力 删除多余的句号',
#  '失望的->失望，适当->不适当',
#  '进用->使用 评估一下自已的活动->评估一下自己的活动',
#  '导求->认为',
#  '纤脚石->关键',
#  '待->待',
#  '搭诚->搭讪',
# ...

# %%
error_trans=[]
for item in reason_list:
    if item.count("->")==1:
        error_trans.append((item.split("->")[0],item.split("->")[1]))
    else:
        for i in item.split(" "):
            if "删除" not in i and i.count("->"):
                error_trans.append((i.split("->")[0],i.split("->")[1]))
            else:
                print(i)
# Out:
# 展露心迹
# 删除1.
# 2.
# 3.
# 4.
# 逗号
# 逗号改为顿号
# 修改中文标点符号
# 修改了错词和标点符号
# 添加句号
# 删除重复词
# 删除一一
# 307-20
# 删除多余的“儿”
# 删除··
# 删除…·
# “一种”
# 修改标点符号和格式
# 删除
# 帮助解决问题
# 在街上打电话给我
# 删除n
# 将都改为的
# 删除多余的逗号
# 吗
# 带进
# 出现了
# 多谈论
# 删除“好吗？”
# 缺少引号闭合
# 删除多余引号
# 出类拔萃
# 添加问号
# 添加冒号
# 添加逗号
# 修改一一为，
# 对待的那样
# 删除多余的逗号
# 修改凭空想象的位置
# 删除逗号
# 修改标点符号
# 有差别吗
# 修改“的脸”为“我吗”
# 添加引号
# 在上课的时候
# 添加的空格
# 删除多余引号，修改错别字
# 瞪了我一眼
# 删除5.
# 删除我
# 添加共同的
# 删除引号
# 在这里
# 另外，
# 讲不出来
# 自己想什么
# 缺少引号
# 添加一个“自己”
# 删除问号后的括号，添加句号
# 删除多余的一个
# 重复词语
# 删除逗号
# 车程怎么样
# 添加逗号
# 添加逗号
# 删除“他”
# 逗号
# 删除前先，修改标点符号
# 修改表达
# 责任
# “时，应既检查文字也检查意象。
# 删除一相当多的事件
# 删除-
# 添加一个
# 相信自己
# 删除多余的引号
# 按日程表
# 删除如何
# 困
# 添加句号
# 删除·
# 删除逗号
# 删除·
# 删除多余的句号
# 负担不起
# 添加逗号
# 删除一
# 删除一一
# 删除逗号
# n
# 删除
# 修改标点符号
# 删除句号
# 怎样度过的
# 修改了句子结构和错词
# 删除逗号
# 修改表达
# 你的父母
# 删除·
# 删除句号
# 修改同女儿为与女儿
# 删除一-
# 生闷气
# 删除逗号
# 在这里
# 添加引号
# 删除重复的“都”
# 勾勒、勃、干帮助、患老、精反应、依然是、尚题
# 双引号
# 修改“要子”为“妻子”
# 删除句子
# 感知觉困难
# 删除引号
# 即使他很挑
# 剔
# 删除的呢
# 删除-—
# 删除重复
# 重要感
# 治疗家庭作业
# 修改了句子结构
# 删除-
# 删除逗号
# 吗
# ...

# %%
## 哎就这样吧，这些拿来备用，然后开始处理 中文
error_trans=[('遵了', '透了'),
 ('刻定', '确定'),
 ('在之前治疗里', '的治疗里'),
 ('“ching-chongchinamen"”', '“ching-chong chinamen”'),
 ('·', '，'),
 ('输', '说'),
 ('喊', '唉'),
 ('迷感', '迷惑不解'),
 ('抱款', '抱歉'),
 ('惠见', '意见'),
 ('生', '生气'),
 ('首光', '首先'),
 ('奖泣', '将这样的事'),
 ('抱您', '抱怨'),
 ('按照', '按照'),
 ('价廉物美', '性价比高'),
 ('计许', '或许'),
 ('··…', '……'),
 ('疫意不', '疲劳不堪'),
 ('读', '讨论'),
 ('谈诺', '谈话'),
 ('一一', '？'),
 ('打粉一下', '打扮一下'),
 ('大包大搅', '大包大揽'),
 ('纤缓', '缓解'),
 ('职贵', '职责'),
 ('本会谈', '本次会谈'),
 ('评有', '也许有 删除--'),
 ('我不知所搭', '我不知所措'),
 ('知遵', '知道 删除· 删除，'),
 ('着着', '拿着'),
 ('一一', ''),
 ('唤', '唉'),
 ('喉', '嗯'),
 ('町', '盯'),
 ('气惯', '气愤'),
 ('咱们', '我们'),
 ('知何呢', '如何呢'),
 ('，', '。'),
 ('·', '空格'),
 ('隐嗨', '隐晦'),
 ('干', '帮'),
 ('患老', '患者'),
 ('事精', '事情'),
 ('精', '更'),
 ('一逮', '一遇'),
 ('一一一', '！'),
 ('筒单', '狭窄'),
 ('知采', '让'),
 ('特', '保'),
 ('结采', '结果'),
 ('喝杂', '杂乱'),
 ('物希望', '希望'),
 ('干帮助', '帮助'),
 ('患老', '对其特定的事精反应'),
 ('更加精确', '更加精确'),
 ('糊糊如生', '模糊'),
 ('唤', '唉'),
 ('了么', '吗'),
 ('想像', '想象'),
 ('隐忽', '忍耐'),
 ('抱发生', '抱歉发生'),
 ('自的', '目的'),
 ('待', '待'),
 ('裹', '哦'),
 ('漫信会', '基督教会'),
 ('练', '练习'),
 ('！”', '！'),
 ('赖', '来'),
 ('毕竞', '毕竟'),
 ('加采', '假如'),
 ('知', '知道'),
 ('忘', '怎'),
 ('蓬字遂可', '明白理解'),
 ('自已', '自己'),
 ('牵', '牵制'),
 ('并', '并不'),
 ('遗当', '适当 删除n'),
 ('国为', '因为'),
 ('知采', '让'),
 ('谨到', '碰到'),
 ('内症', '内疚'),
 ('抱款', '抱歉'),
 ('心不在', '心不在焉'),
 ('忘么样', '怎么样'),
 ('间题', '问题'),
 ('使你更适当些·…·……·', '使你更适当些...或者'),
 ('热表', '热衷'),
 ('产生兴趣吧', '产生兴趣。'),
 ('团体', '团队'),
 ('急么', '想 添加逗号'),
 ('哭泣l', '哭泣 删除一一'),
 ('胸…', '胸'),
 ('很', '对 添加逗号'),
 ('很对', '很重要'),
 ('崩清', '崩溃'),
 ('升么', '怎么'),
 ('你室友', '你的室友'),
 ('谨', '坚'),
 ('去妆投', '去找他们'),
 ('请求帮助我也很为难', '请求帮助也让我很为难'),
 ('显露了', '暴露了'),
 ('很少次', '很少有次'),
 ('冷淡', '不友善'),
 ('仅仪', '仅仅'),
 ('教投', '教授'),
 ('一一', '更多'),
 ('不想谈', '不想谈，'),
 ('乘地铁', '乘坐地铁'),
 ('意么样', '怎么样'),
 ('宿含', '宿舍'),
 ('逆', '逛'),
 ('教授说什么了？我漏掉什么了没有？现在我不知道该怎么办了。寰语', '口头语'),
 ('；', '，'),
 ('忘样', '忘记'),
 ('总', '样'),
 ('隐忍', '忍耐'),
 ('以栖', '以牺牲'),
 ('患于', '想'),
 ('忘么样了', '然后呢'),
 ('狠', '很'),
 ('接操', '调整'),
 ('性致益然', '性致勃发'),
 ('周图', '周围'),
 ('党', '会'),
 ('意样', '如何'),
 ('屑', '眉'),
 ('挑', '挑衅'),
 ('何不', '为什么不'),
 ('筷', '会'),
 ('一一样', '一样'),
 ('加果', '假设'),
 ('了·', '，或……或'),
 ('心靡', '心扉'),
 ('患老', '患者'),
 ('精反应', '精确反应'),
 ('删除做 不适当', '不合适'),
 ('一下子', '一下 删除逗号'),
 ('二个', '两个'),
 ('结采', '结果'),
 ('糖糕', '糟糕'),
 ('电视频遵', '电视剧'),
 ('一一', '在'),
 ('怎么', '怎么'),
 ('惊极了', '惊讶极了'),
 ('千', '谦'),
 ('给子肯定', '给予肯定'),
 ('例才', '刚才'),
 ('一一', '——'),
 ('过- ', ' 过'),
 ('司空见惯', '司空见惯的'),
 ('1米93', '1米93，'),
 ('计许', '也许'),
 ('加果', '加上'),
 ('壹', '毫'),
 ('成千', '成不'),
 ('劳叻', '才'),
 ('急样', '怎样'),
 ('置里', '里'),
 ('如采', '如果'),
 ('遗当', '适当'),
 ('自前', '自己'),
 ('病苦', '不愉'),
 ('儿', '一些'),
 ('注意想', '注意力想'),
 ('如采', '如果'),
 ('一一起', '一起'),
 ('约输', '约翰'),
 ('唤', '称 删除句号 添加引号'),
 ('困感', '困惑 删除逗号'),
 ('离 ', ' 篇'),
 ('况获不语', '交谈'),
 ('一一', ''),
 ('怒一一', '怒，尽管'),
 ('详多', '几'),
 ('夏天的决定', '度过夏天的决定'),
 ('志您', '职业发展'),
 ('后面部', '背后都有'),
 ('不必要', '不需要'),
 ('做', '再讨论'),
 ('急', '如此'),
 ('犹', '犹豫'),
 ('千得', '操作得'),
 ('的伤', '伤'),
 ('届', '眉'),
 ('来', '来访者'),
 ('一一', '一是 焦虑'),
 ('变糖', '变差'),
 ('剧', '刚'),
 ('至曲', '偏曲'),
 ('加', '感'),
 ('例加', '例如'),
 ('”', '”'),
 ('失望的', '失望，适当'),
 ('自的', '最终'),
 ('其时其地', '在那时那地'),
 ('愚妻', '愚蠢'),
 ('抱想', '抱怨 删除一一'),
 ('担白', '但白'),
 ('ey', '说'),
 ('充实', '补充'),
 ('糖糕', '糟糕'),
 ('撞了上去', '撞上去了'),
 ('熟恶', '熟悉'),
 ('争吵', '争论'),
 ('急样', '急迫'),
 ('De而', '但'),
 ('·.·', '，我不确定'),
 ('也评', '我们也评估了'),
 ('扮演', '实践'),
 ('压倒了受没受伤', '被复印机压倒了受没受伤'),
 ('唤', '唉'),
 ('魅', '虽然'),
 ('糖', '糟'),
 ('慧者', '来访者'),
 ('一', '一部分'),
 ('如采', '如果 删除逗号'),
 ('儿种', '哪种'),
 ('坏消急', '坏消息'),
 ('可能不像', '可能不像'),
 ('惠蠢', '愚蠢'),
 ('展', '晚'),
 ('例莎', '莎'),
 ('在会谈继续下去之前', '在会谈继续之前'),
 ('访', '但是 删除．．．．'),
 ('一一', '之间'),
 ('自已', '自己'),
 ('响', '影'),
 ('哀衰', '悲伤'),
 ('提', '提要求'),
 ('会读', '会话'),
 ('想像', '想象'),
 ('么', '吗'),
 ('接', '授'),
 ('如采', '如果'),
 ('喉', '嗓'),
 ('蜗居', '窝居'),
 ('来', '我的 删除一一'),
 ('访', '放'),
 ('空等', '徒等'),
 ('教投', '教授'),
 ('浪资', '浪费'),
 ('千脆', '千方百计'),
 ('争', '争吵'),
 ('诀', '交'),
 ('地', '也'),
 ('效益', '效率'),
 ('糖糕', '糟糕'),
 ('糖糕', '差劲'),
 ('町', '盯'),
 ('无法去做', '无法进行'),
 ('着了', '看了'),
 ('糖糕', '好笑'),
 ('约输', '孩子们'),
 ('履', '练'),
 ('博敢', '博取'),
 ('无动于表', '无动于衷'),
 ('咱们', '我们'),
 ('顾间问', '顾问'),
 ('如采', '如果'),
 ('意样', '应该'),
 ('如何去', '如何'),
 ('事先做-一个', '事先做一个'),
 ('没有-张', '没有一张'),
 ('Wes治疗师 来访者hilly', 'Wesley'),
 ('一一', '吗'),
 ('地', '的'),
 ('糖糕', '糟糕'),
 ('如采', '如果'),
 ('：', '，'),
 ('影啊', '影响'),
 ('感变', '感受'),
 ('叫', '觉得'),
 ('不延确', '不正确'),
 ('本还', '那还'),
 ('首做', '曾做'),
 ('精', '惊'),
 ('自已', '自己'),
 ('诠释', '解释'),
 ('遥', '要'),
 ('间', '一下'),
 ('今您', '当您'),
 ('会', '会面'),
 ('好转', '有所改善'),
 ('是大的', '很大的'),
 ('你最为', '你最在乎的'),
 ('纤脚石', '关键'),
 ('基至', '并不一定'),
 ('揭蛋', '捣蛋'),
 ('解党', '解脱'),
 ('宽想', '宽容'),
 ('心意马了', '焦虑了'),
 ('反夏', '反复'),
 ('第一一次', '第一次'),
 ('时筷', '时候'),
 ('掀', '翻'),
 ('一一', '是'),
 ('预言', '预想'),
 ('许可行', '可能行'),
 ('婚烟', '婚姻'),
 ('PDG', '情绪'),
 ('慈', '惹'),
 ('这样想它', '这样想，自我批评的或如果'),
 ('千', '干'),
 ('确定集', '确定'),
 ('是否', '是否'),
 ('外', ''),
 ('情境', '情况'),
 ('扫兴', '扫了兴'),
 ('教控', '教授'),
 ('展练课', '早练课'),
 ('-一个', '但一个'),
 ('思维要是', '如果思维是'),
 ('自已', '自己'),
 ('终归', '总归'),
 ('不是么', '不是吗'),
 ('早展', '早上'),
 ('驳', '驶'),
 ('悔清断', '清晰的画面'),
 ('差愧', '感到愧疚'),
 ('感到', '觉得'),
 ('纤脚石', '绊脚石'),
 ('困了', '困惑了'),
 ('期白 ', ' 弄清'),
 ('一一', '“一一”'),
 ('步', '遵'),
 ('知遵', '知道'),
 ('外限', '最后'),
 ('合理一情绪', '合理的情绪'),
 ('忘', '怎'),
 ('一这样', '这样'),
 ('愿暴', '错误'),
 ('党得', '当得'),
 ('认比', '认为'),
 ('儿', '地'),
 ('闲尾炎', '阑尾炎'),
 ('一一', '会'),
 ('势力', '努力'),
 ('Pe', '困难的'),
 ('忘样', '忘记样'),
 ('情说', '情绪'),
 ('维', '记录'),
 ('花', '会'),
 ('一巨', '一旦'),
 ('衰叹', '抱怨'),
 ('贵任', '权利'),
 ('教', '太'),
 ('挥港', '挥动'),
 ('被抛弃感·', '被抛弃感'),
 ('进行的', '做的'),
 ('懂憬', '憧憬'),
 ('旁力', '努力'),
 ('塑', '塑造'),
 ('势力', '努力'),
 ('抱款', '抱歉'),
 ('内、抑郁和自我贵备', '内疚、沮丧和自责'),
 ('读读', '所说的事'),
 ('刚才', '几分钟前'),
 ('去', '应该去'),
 ('一11:00', '11:00'),
 ('面', '范围'),
 ('搭诚', '搭讪'),
 ('性表演', '下降'),
 ('蜗', '躺'),
 ('如采', '如果'),
 ('问间', '问题'),
 ('失数', '失去'),
 ('避到', '避免'),
 ('至曲', '至关重要的'),
 ('您想', '您觉得'),
 ('亭忘', '怎么样'),
 ('早来儿', '提前五 删除填 删除逗号'),
 ('履', '练'),
 ('干', '千'),
 ('读谈', '重新'),
 ('标', '打'),
 ('展', '晨'),
 ('忘样', '忘掉了什么'),
 ('扣何', '怎么办'),
 ('如采', '如果'),
 ('最今', '最 让你不安的部分'),
 ('贵', '责'),
 ('辨辩论', '辨辩论'),
 ('覆辙', '度辙'),
 ('相似', '相似'),
 ('栖牲', '牺牲'),
 ('恶维迟缓', '恶劣思维'),
 ('慧伤', '伤害'),
 ('剪', '偶'),
 ('删除多余逗号，奖', '休'),
 ('站了', '站在'),
 ('不适感能', '不适感能'),
 ('会读', '会谈'),
 ('回颜', '回想'),
 ('势力', '努力'),
 ('每日', '每天'),
 ('一一', '。'),
 ('信念', '的信念 删除逗号'),
 ('挫折惑', '挫折困惑'),
 ('图着', '坐着'),
 ('计许', '也许'),
 ('读', '谈'),
 ('读', '减'),
 ('么样', '吧'),
 ('建议什么', '强求什么'),
 ('呢', '那'),
 ('究竞', '究竟'),
 ('忘样', '怎样'),
 ('导求', '认为'),
 ('报', '很'),
 ('难说', '可能'),
 ('文发现', '发现自己'),
 ('一一', '一一'),
 ('对么', '对吗'),
 ('据治疗前我们所谈的', '根据我们之前的谈话 这是通常你如何看待你势力的态度吗？即知采你不尽可能地势力工作，你就会失败？'),
 ('浪贵', '浪费'),
 ('狠多', '很多'),
 ('您儿', '您'),
 ('再问您儿', '再问您'),
 ('急么', '怎么'),
 ('我如果', '如果'),
 ('看起来就是', '现在看起来'),
 ('烧好晚饭', '做好晚饭'),
 ('千成了', '成了'),
 ('发牌气', '发脾气'),
 ('贵备', '打败'),
 ('范图', '范围'),
 ('竞然', '竟然'),
 ('不负贵任', '不负责任'),
 ('呢 ', ' 嗯'),
 ('++删除 你想让地相信什么？ 慧者', '治疗师'),
 ('唤', '喊'),
 ('考好一点的', '考得好一点'),
 ('在你心理上', '对你心理上'),
 ('感衰', '感到沮丧'),
 ('标是', '是否'),
 ('忘样', '尝试'),
 ('一一', '——'),
 ('评', '也许'),
 ('劳力', '努力'),
 ('该', '本该'),
 ('文', '内容'),
 ('知遵', '知道'),
 ('简单', '糊涂'),
 ('忘样', '主动'),
 ('儒弱', '如此弱 添加逗号'),
 ('找些', '找 删除单独'),
 ('写究了', '写完了'),
 ('材料', '情况'),
 ('部 ', ' 感'),
 ('抱', '抱歉'),
 ('oo', '你'),
 ('胆', '胆怯'),
 ('一一一', '——'),
 ('影啊', '影响'),
 ('似手', '似乎'),
 ('自已', '自己'),
 ('相千', '相干'),
 ('敲', '让'),
 ('究成了', '成功了'),
 ('一一', '使'),
 ('一', '，'),
 ('惯过', '感到'),
 ('一一', '：'),
 ('使便', '我们'),
 ('找出', '找出'),
 ('看到', '感受到'),
 ('时筷', '时候'),
 ('地', '她'),
 ('慈者', '来访者'),
 ('结采', '结果'),
 ('一决定', '开始'),
 ('一开始', '开始'),
 ('歌期', '阶段间'),
 ('一一', '，'),
 ('呈期', '期间'),
 ('料信', '认为'),
 ('而宜', '而且'),
 ('此时此刻', '此前'),
 ('修改错别字 他们之中', '他们之间'),
 ('患策', '糊涂'),
 ('戒进来', '加入治疗之前 训练我作些事'),
 ('形像', '形象'),
 ('更严房', '更严肃'),
 ('不爱去', '不愿去'),
 ('精', '患'),
 ('及', '和'),
 ('更好些', '更好一些'),
 ('好好的', '好好地'),
 ('究全', '将 彻底驱散 显出来'),
 ('110', '要'),
 ('内', '内疚'),
 ('一一', '一'),
 ('会谈', '次谈话'),
 ('仗', '拿'),
 ('出', '拿出'),
 ('自已', '自己'),
 ('胶旺', '紧皱'),
 ('好转', '改善'),
 ('挎掉了', '崩掉了'),
 ('62·', '到'),
 ('因而', '因此'),
 ('受伤害', '受伤的'),
 ('回到', '返回'),
 ('抱事情', '抱歉事情'),
 ('现念', '想法'),
 ('感意', '愿意'),
 ('渍', '溃'),
 ('儿乎', '几乎'),
 ('掌习', '掌握'),
 ('一一', '，'),
 ('糕', '糟'),
 ('思维您', '您的思维'),
 ('如装', '如发现'),
 ('水远', '虽然'),
 ('删除多余符号；并不时', '时而'),
 ('依靠', '依赖'),
 ('鼓门', '敲门'),
 ('大事化小', '夸大化'),
 ('抱想', '表达'),
 ('添加逗号 删除一而 不是所说的话', '而不是所说的话 添加逗号 删除一一 删除一一'),
 ('差辱', '差错'),
 ('儿项', '其中的几项'),
 ('忘样', '怎样'),
 ('如采', '如果'),
 ('程序及', '程序和'),
 ('利辨', '利弊'),
 ('教投', '监考'),
 ('开始者', '开始做'),
 ('究竞', '究竟'),
 ('一困想', '一瞬间'),
 ('让你有多烦 吗', '吗？'),
 ('合理一情绪', '合理的情绪'),
 ('知过作', '知道'),
 ('救师', '教师'),
 ('如采用', '如果采用'),
 ('水乎', '水平'),
 ('餐', '早餐'),
 ('务力', '努力'),
 ('猛然', '突然'),
 ('亏次', '亏欠'),
 ('署假', '所做'),
 ('一一', '甚至'),
 ('唯晚', '昨晚'),
 ('膜', '敏感'),
 ('会读', '会谈'),
 ('一一', '：'),
 ('内江', '内讧'),
 ('我想', '我以为'),
 ('闲曦', '闲暇'),
 ('究', '尽快地做一些'),
 ('女儿唐尼弗', '女儿唐妮弗'),
 ('狠多', '很多'),
 ('他妈的', '他妈的这种气'),
 ('第-一次', '第一次'),
 ('糕的', '糟糕的'),
 ('如采', '如果'),
 ('应讨卡', '应对卡'),
 ('问闷不乐', '闷闷不乐'),
 ('拆住', '记住'),
 ('贵任', '责任'),
 ('糖糕', '变糟糕'),
 ('疲意不堪', '疲劳不堪'),
 ('如采', '如若'),
 ('帮时', '当时'),
 ('患肺爽', '患了感冒'),
 ('忘么', '什么'),
 ('严房', '严肃'),
 ('摆脱', '避开'),
 ('恶考', '想象'),
 ('如采', '如果'),
 ('一率', '它'),
 ('栖性', '牺性'),
 ('毕竞', '毕竟'),
 ('住在一起,', '住在一起，'),
 ('消概', '消极'),
 ('臂如是', '那有哪些'),
 ('意么样', '意思样式 删除··'),
 ('志感', '志愿'),
 ('容忽', '忽视'),
 ('今天早严', '今天早晨'),
 ('惊评', '惊讶'),
 ('VallyForge', 'Valley Forge'),
 ('想像', '想象'),
 ('吵着地', '与她吵架'),
 ('的是', '得到'),
 ('疲意', '疲倦'),
 ('使便', '指导 你认为这清楚吗？'),
 ('关于', '关于'),
 ('间意', '建议'),
 ('下面', '接下来'),
 ('如采', '如果'),
 ('发据', '根据'),
 ('势力', '努力 删除多余的句号'),
 ('感觉，', '感觉”'),
 ('趾高气扬的', '趾高气扬 逗号改为句号'),
 ('烦态', '烦躁'),
 ('惠伤', '受伤'),
 ('知遵', '不知道'),
 ('办公来', '办公室'),
 ('权衡一下帐淳', '权衡一下账单'),
 ('忘样', '忘掉'),
 ('真正1', '真正'),
 ('争取每天完战一-次', '争取每天完成一次'),
 ('一．种', '一种'),
 ('像打字·样', '像打字一样'),
 ('预言', '预测'),
 ('会谈', '次会谈'),
 ('需时', '需要'),
 ('文夫', '丈夫'),
 ('右边的', '右边的栏目，请它'),
 ('会读', '次会议'),
 ('如采', '如果'),
 ('真得', '真的'),
 ('作升', '做家庭作业'),
 ('衰该', '克服困难的方法'),
 ('脆等', '寻求'),
 ('推测当', '推测，当'),
 ('能做不好 详', '知道'),
 ('愿蠢', '愚蠢'),
 ('墨梦', '梦 删除么后的问号'),
 ('如采', '如果'),
 ('你议为', '你觉得'),
 ('能做的事情', '其他的选择'),
 ('其他的选择', '其他的办法'),
 ('一一一', '，'),
 ('评估一下自已的活动', '评估一下自己的活动'),
 ('诀谈', '进行'),
 ('忽不住', '忍不住'),
 ('群', '样 删除句号'),
 ('使宜', '事宜'),
 ('比', '比如'),
 ('准务', '确认'),
 ('一一', '请注意'),
 ('算命', '悲观'),
 ('评', '能'),
 ('轴尼', '抽屉'),
 ('惠伤', '挥舞'),
 ('遗撼', '遗憾'),
 ('意么样', '意味着什么样'),
 ('自已', '自己'),
 ('牵', '牵扯'),
 ('没有效', '没有效果')]

# %%
# 载入
import json
input_file_path="/home/ckqsudo/code2024/0dataset/E-bed/Chinese/中文数据_处理错reasoning_分离长对话数据_分离label_对话人.json"
with open(input_file_path,"r",encoding="utf-8") as i_f:
    cn_data=json.load(i_f)

# %%
idx_dialog_dict["0"]
# Out:
# [{'id': '0-0',
#   'participant': '治疗师',
#   'text': '你能想象你自己坐上时间机器回到了过去，然后遇见了小时候的自己吗？',
#   'reason': ''},
#  {'id': '0-1', 'participant': '来访者', 'text': '是的，我想我可以。', 'reason': ''},
#  {'id': '0-2',
#   'participant': '治疗师',
#   'text': '那么你希望坐着时间机器回到多久前的过去呢？你希望遇见多小的自己，并帮助她改变自我？',
#   'reason': ''},
#  {'id': '0-3', 'participant': '来访者', 'text': '我希望看到十岁时的自己。', 'reason': ''},
#  {'id': '0-4',
#   'participant': '治疗师',
#   'text': '那好，现在时间机器已经带着你回到了过去。现在，请想象你走出了时间机器，你看见一个小女孩。那就是你，童年的你，十岁。她上上下下地打量着你，但是并没有意识到她其实看见的就是成年后的自己。但是这个童年的你对你有着特别的感觉，她将会十分在意你对她说的任何话。想象一下你给了童年的你一个拥抱。现在你希望就你父亲的说教向童年的你说些什么？',
#   'reason': ''},
#  {'id': '0-5',
#   'participant': '来访者',
#   'text': '现在的你会告诉童年的你，她的父亲彻底误导了她，并且童年的你要十分留意父亲强加给她的那种宗教内疚感。',
#   'reason': ''}]

# %%
# cn_data[0]

# %%
# dialog_id=0
# cn_dialog_data=[]
new_cn_data=[]
for x,item in enumerate(cn_data):
    if item['key']=="fewshot":
        unit_idx=item["unit_id"]
        if str(unit_idx) in idx_dialog_dict:
            post_gpt_dialog_list=idx_dialog_dict[str(unit_idx)]
            if len(item['dialog'])!=len(post_gpt_dialog_list):
                print(unit_idx,len(item['dialog']),post_gpt_dialog_list)
            for y,dialog_item in enumerate(item['dialog']):
                for z,post_item in enumerate(post_gpt_dialog_list):
                    if dialog_item["id"]==post_gpt_dialog_list[z]["id"]:
                        item['dialog'][y]["text"]=post_gpt_dialog_list[z]['text']
        else:
            assert  unit_idx in error_index_list  
        # 
    new_cn_data.append(item)
# Out:
# 18 24 [{'id': '18-0', 'participant': '来访者', 'text': '我发现当我和你交流的时候，我似乎总是十分小心谨慎。那种被理解的感受对我而言十分重要，而有时我怀疑你是否能真正理解我面对的问题，因为我是女性，而你是个男的。', 'reason': '删除多余符号，修改表达'}, {'id': '18-1', 'participant': '治疗师', 'text': '我很高兴你愿意和我分享你在尝试信任我的时候出现的问题。我希望你不要过分在意你对我所说的话，我也十分愿意理解你。可能你能告诉我关于焦虑一一关于我是否能够理解作为女性的你的信息。', 'reason': '修改表达'}, {'id': '18-2', 'participant': '来访者', 'text': '还不像你说的那么严重，但是我还是很担心，不得不小心翼翼地和你交流。我不知道你会如何判断我、回应我。', 'reason': '修改表达'}, {'id': '18-5', 'participant': '治疗师', 'text': '是什么让你觉得我无法理解作为女性的你呢？也许你可以和我说说是什么因素让你觉得阻碍了我们的交流过程。', 'reason': '修改表达'}, {'id': '18-6', 'participant': '来访者', 'text': '到目前为止，没有一个男人真正地愿意倾听我的讲述。我尽自己的全力去取悦别人一一先是我父亲，之后是约翰。我怀疑你是否能理解我为什么这么需要别人一一先是我父亲，之后是约翰来让我体会自己作为女性的价值所在。', 'reason': '修改表达'}, {'id': '18-16', 'participant': '来访者', 'text': '当我开始懂得去感受的时候，我常常会感到混乱。我常常觉得自己没有权利去产生感受一一无论是生气、兴奋、沮丧或是别的什么。我要做的就是像老黄牛那样辛勤工作，一声不响。', 'reason': '修改表达'}, {'id': '18-20', 'participant': '来访者', 'text': '想，我不确定他们是不是真的对我的感受感兴趣。', 'reason': '修改表达'}]
# ...

# %%
reasoning_list=[]

# %%
import json
with open(r"/home/ckqsudo/code2024/0dataset/E-bed/Chinese/中文数据_GPT重新处理对话.json","w") as o_f:
    json.dump(new_cn_data,o_f,ensure_ascii=False)

# %%
error_trans
# Out:
# [('遵了', '透了'),
#  ('刻定', '确定'),
#  ('在之前治疗里', '的治疗里'),
#  ('“ching-chongchinamen"”', '“ching-chong chinamen”'),
#  ('·', '，'),
#  ('输', '说'),
#  ('喊', '唉'),
#  ('迷感', '迷惑不解'),
#  ('抱款', '抱歉'),
#  ('惠见', '意见'),
#  ('生', '生气'),
#  ('首光', '首先'),
#  ('奖泣', '将这样的事'),
#  ('抱您', '抱怨'),
#  ('按照', '按照'),
#  ('价廉物美', '性价比高'),
#  ('计许', '或许'),
#  ('··…', '……'),
#  ('疫意不', '疲劳不堪'),
#  ('读', '讨论'),
#  ('谈诺', '谈话'),
#  ('一一', '？'),
#  ('打粉一下', '打扮一下'),
#  ('大包大搅', '大包大揽'),
#  ('纤缓', '缓解'),
#  ('职贵', '职责'),
#  ('本会谈', '本次会谈'),
#  ('评有', '也许有 删除--'),
#  ('我不知所搭', '我不知所措'),
#  ('知遵', '知道 删除· 删除，'),
#  ('着着', '拿着'),
#  ('一一', ''),
#  ('唤', '唉'),
#  ('喉', '嗯'),
#  ('町', '盯'),
#  ('气惯', '气愤'),
#  ('咱们', '我们'),
#  ('知何呢', '如何呢'),
#  ('，', '。'),
#  ('·', '空格'),
#  ('隐嗨', '隐晦'),
#  ('干', '帮'),
#  ('患老', '患者'),
#  ('事精', '事情'),
#  ('精', '更'),
#  ('一逮', '一遇'),
#  ('一一一', '！'),
#  ('筒单', '狭窄'),
#  ('知采', '让'),
#  ('特', '保'),
#  ('结采', '结果'),
#  ('喝杂', '杂乱'),
#  ('物希望', '希望'),
#  ('干帮助', '帮助'),
# ...

# %%
with open(r"/home/ckqsudo/code2024/0dataset/E-bed/Chinese/错误词表.txt","w") as w_f:
    w_f.write(str(error_trans))
